# %%
import pandas as pd
unrate=pd.read_excel("/home/santosh/UNRATE.xls")
unrate["DATE"]=pd.to_datetime(unrate["DATE"])
print(unrate['DATE'])
print (unrate[0:12])
# Out:
# 0     1948-01-01
# 1     1948-02-01
# 2     1948-03-01
# 3     1948-04-01
# 4     1948-05-01
# 5     1948-06-01
# 6     1948-07-01
# 7     1948-08-01
# 8     1948-09-01
# 9     1948-10-01
# 10    1948-11-01
# 11    1948-12-01
# 12    1949-01-01
# 13    1949-02-01
# 14    1949-03-01
# 15    1949-04-01
# 16    1949-05-01
# 17    1949-06-01
# 18    1949-07-01
# 19    1949-08-01
# 20    1949-09-01
# 21    1949-10-01
# 22    1949-11-01
# 23    1949-12-01
# 24    1950-01-01
# 25    1950-02-01
# 26    1950-03-01
# 27    1950-04-01
# 28    1950-05-01
# 29    1950-06-01
#          ...
# 799   2014-08-01
# 800   2014-09-01
# 801   2014-10-01
# 802   2014-11-01
# 803   2014-12-01
# 804   2015-01-01
# 805   2015-02-01
# 806   2015-03-01
# 807   2015-04-01
# 808   2015-05-01
# 809   2015-06-01
# 810   2015-07-01
# 811   2015-08-01
# 812   2015-09-01
# 813   2015-10-01
# 814   2015-11-01
# 815   2015-12-01
# 816   2016-01-01
# 817   2016-02-01
# 818   2016-03-01
# 819   2016-04-01
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(unrate["DATE"][:12],unrate["VALUE"][:12])
plt.show()

# %%
yval=unrate["VALUE"][0:12]
xval=unrate["DATE"][0:12]
plt.plot(unrate["DATE"][0:12],unrate["VALUE"][0:12])
plt.xticks(xval.tolist(),xval,rotation=90)
plt.yticks(yval.tolist(),yval)
plt.show()

# %% [raw]
# yval=unrate["VALUE"][0:12]
# xval=unrate["DATE"][0:12]
# plt.plot(unrate["DATE"][0:12],unrate["VALUE"][0:12])
# plt.xticks(xval.tolist(),xval,rotation=90)
# plt.yticks(yval.tolist(),yval)
# plt.xlabel("Month")
# plt.ylabel("Unemployment Rate")
# plt.title("Unemployment rate, Yearly")
# plt.show()
